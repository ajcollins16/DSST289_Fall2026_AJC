# %% [markdown]
# <a href="https://colab.research.google.com/github/ajcollins16/DSST289_Fall2026_AJC/blob/main/Notebooks/Notebook06_Review1_5_SV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook 06 — Exam 1 Review

# %% [markdown]
# **Main Objective**
#
# - Review the following Data Manipulation Techniques
#
#     1. Sorting
#     2. Filtering
#     3. Grouping
#     4. Variable Creation
#     5. Summarizing/Aggregating
#     6. Piping

# %% [markdown]
# ## Setup
#
# Please run the setup code below

# %%
! wget -q -nc https://raw.githubusercontent.com/taylor-arnold/fds-py/refs/heads/main/funs.py

from funs import *

# %%
import numpy as np
import polars as pl

from plotnine import *
from polars import col as c
theme_set(theme_minimal())

path = "https://raw.githubusercontent.com/ajcollins16/DSST289_Fall2026_AJC/refs/heads/main/"

# %%
dat = pl.read_csv(path + "Data/metro.csv")

# %% [markdown]
# ## Review Day
#
# This notebook is a review of the data manipulation techniques we have learned so far. We will work with the `metro` dataset, which contains information about US metropolitan areas from the [American Community Survey](https://www.census.gov/programs-surveys/acs/about.html), which is just a yearly (optional) census to assess various community and state factors. The datset includes variables such as population (in millions), population density, median age, median household income, home ownership rates, median rent for a one-bedroom apartment, and geographic information including which census division each metro area belongs to.

# %% [markdown]
# ### Questions
#
# 1. Sort the metropolitan areas by population, with the largest metros at the top

# %% [markdown]
# 2. Find the metro area with the highest median household income.

# %% [markdown]
# 3. Sort the data by median age, with the youngest metros first.

# %% [markdown]
# 3. What places have the youngest population (list the top three)?
#
# **Answer (Q3):**

# %% [markdown]
# 4. Select only the metro areas located in the South (where the `quad` column equals "S").

# %% [markdown]
# 5. Select the metros that have a population density greater than 500 people per square mile.

# %% [markdown]
# 6. Find the metros where residents spend more than 30 percent of their income on rent.

# %% [markdown]
# 7. Select the metros that are in either the Pacific or New England division

# %% [markdown]
# 8. Find metros in the South that have a median household income above $80,000. Use two separate filter steps.

# %% [markdown]
# 9. For each division, compute the average median household income and the number of metros in that division.

# %% [markdown]
# 10. Find the most populous metro area in each quadrant (i.e., `quad`) of the country.

# %% [markdown]
# 11. The population in our dataset is given in millions, create a new column that shows the population in thousands instead.

# %% [markdown]
# 12. Create a new column that computes the annual rent for a one-bedroom apartment (the current rent column shows monthly rent).

# %% [markdown]
# 13. The median household income is given as an exact figure, but it can be useful to round it. Create a new column that rounds the income to the nearest $10,000. Hint: Use the same integer division technique we used for computing decades from years.

# %% [markdown]
# 14. Now, count how many metro areas fall into each income bracket (rounded to the nearest $10,000).

# %% [markdown]
# 15. For each census division, find the metro area with the lowest median rent. Sort the final result alphabetically by division name.

# %% [markdown]
# 16. Find the divisions that have more than 75 metro areas. Show the average home ownership rate for each of these divisions, sorted from highest to lowest ownership rate.

# %% [markdown]
# 17. For each division with more than 75 metro areas, show the name of the metro with the highest population density. Use `print_rows` to display all results.
