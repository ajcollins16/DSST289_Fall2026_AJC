# %% [markdown]
# <a href="https://colab.research.google.com/github/ajcollins16/DSST289_Fall2026_AJC/blob/main/Notebooks/Notebook10_DataVis4_SV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook 10 — Data Visualization Four

# %% [markdown]
# **Main Objective**
#
# 1. Multiple Datasets
# 2. Plot Faceting
# 3. Plot Labeling
# 4. Visual Theme Editing

# %% [markdown]
# ## Setup
#
# Please run the setup code below

# %%
! wget -q -nc https://raw.githubusercontent.com/taylor-arnold/fds-py/refs/heads/main/funs.py

from funs import *

# %%
import numpy as np
import polars as pl

from plotnine import *
from polars import col as c
theme_set(theme_minimal())

path = "https://raw.githubusercontent.com/ajcollins16/DSST289_Fall2026_AJC/refs/heads/main/"

# %%
dat = pl.read_csv(path + "Data/food.csv")

# %% [markdown]
# ## More Data Visualization Edits
#
# Today we are going to be working with the `food` dataset again. We will be using it to review four main concepts that were brought up in the reading. Those being:
#
# - Multiple Datasets -> The practice of combining datasets into a single visual to further emphasize the information you want to present.
# - Faceting -> Practice of plotting similar visuals based on some categorical variable.
# - Data Labels -> The practice of adding labels like a (sub-)title or caption (among others that we won't cover) as well as editing the axis or graphical aesthetic labels like color.

# %% [markdown]
# ### Questions
#
# 1. Create a histogram of the calorie content of the foods in the dataset. Use a bin width of 25 calories.

# %% [markdown]
# 2. Create a boxplot showing the distribution of protein content for each food group. Order the categories in the plot by their protein amount.

# %% [markdown]
# We will look again at the smaller dataset of food items today to get a sense of how the final set of graphic commands works. Start by picking a fun color from the [Color Wheel](https://htmlcolorcodes.com/color-wheel/). We will use this throughout the notebook.
#
# 3. Start by creating a dataset containing only dairy products. Then, plot the full `food` dataset with total fat on the x-axis and calories on the y-axis creating a scatterplot. Color these points in light grey (`#d3d3d3`). Layer the dairy products on top using the accent color that you selected as well as change the size of the dots to be much larger than the others.

# %% [markdown]
# 4. Now add the names of the dairy products to the plot. Use your accent color for the text and add a vertical nudge so the labels don't overlap with the points.

# %% [markdown]
# 5. Create a scatter plot of total fat versus calories, with the points colored by food group. Use faceting to create a separate panel for each food group. Since the color and facet show the same information, hide the legend.

# %% [markdown]
# 6. Create a scatter plot of total fat versus calories, colored by food group. This time, add informative manually created labels: a title, subtitle, caption, and clear axis and legend labels.
