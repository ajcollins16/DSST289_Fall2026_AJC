# %% [markdown]
# <a href="https://colab.research.google.com/github/ajcollins16/DSST289_Fall2026_AJC/blob/main/Notebooks/Notebook09_DataVis3_SV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook 09 — Data Visualization Three

# %% [markdown]
# **Main Objective**
#
# 1. Visualizing Statistics
# 2. Changing Scales

# %% [markdown]
# ## Setup
#
# Please run the setup code below

# %%
! wget -q -nc https://raw.githubusercontent.com/taylor-arnold/fds-py/refs/heads/main/funs.py

from funs import *

# %%
import numpy as np
import polars as pl

from plotnine import *
from polars import col as c
theme_set(theme_minimal())

path = "https://raw.githubusercontent.com/ajcollins16/DSST289_Fall2026_AJC/refs/heads/main/"

# %%
movieDat = pl.read_csv(path + "Data/movies_50_years.csv")

# %% [markdown]
# ## Statistics and Scales
#
# Today we are going to be extending our understanding on visualizing data by introducing the idea of visualizing statistical information. These will come in the form of new plot types that visualize descriptive statistics or other data summarizing information. In addition we will be going over some minor but important changes to how the information is being scaled on the x- and/or y-axis.
#
# We will be usiong the `movie` dataset which includes information about each film's runtime (in minutes), release year, MPA rating (G, PG, PG-13, R), IMDB rating, and the number of ratings a movie has recieved.

# %% [markdown]
# ### Questions
#
# 1. Start by creating a histogram of movie runtime.

# %% [markdown]
# 2. The default bin settings make it hard to interpret. Modify your histogram to use a bin width of 10 minutes, with bins starting at 0.

# %% [markdown]
# 3. There are some extremely long films in the dataset. Filter to keep only movies shorter than 3 hours, convert the runtime to hours, and create a histogram with 15-minute bins (thats 0.25 hours).

# %% [markdown]
# 3. Within a 15-minute bucket, what is the most popular duration for a film in this dataset?
#
# **Answer (Q3):**

# %% [markdown]
# 4. Create a boxplot (box-and-wisker classically called) showing the distribution of runtime for each MPA rating category.

# %% [markdown]
# 5. Let's see how runtimes have changed over time. Filter to keep movies under 3 hours, create a column for the 5-year period each movie belongs to, and make a boxplot of runtime by period. Use `factor()` around the period variable so that it is treated as a categorical variable. Hint: The 5-year period can be done the same way we did for decades, but now with 5 replacing 10 in the integer division.

# %% [markdown]
# 6. Now let's look at how audience engagement has changed. Group the data by 5-year periods and compute the average number of ratings per movie in each period. Create a scatter plot of this trend and add a linear trend line.

# %% [markdown]
# 7. Filter to just movies from 2010 and create a scatter plot with the number of ratings on the x-axis and the IMDB rating on the y-axis. Color the points by MPA rating using the color-blind friendly color scale.

# %% [markdown]
# 8. The rating counts span a huge range, making most points cluster on the left. Modify the previous plot to use a logarithmic scale on the x-axis so we can better see the full distribution.
