# %% [markdown]
# <a href="https://colab.research.google.com/github/ajcollins16/DSST289_Fall2026_AJC/blob/main/Notebooks/Notebook04_DataManipulation2_SV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook 04 — Data Manipulation Two

# %% [markdown]
# **Main Objective**
#
# 1. Grouping
# 2. Variable Creation (Adding Columns)

# %% [markdown]
# ## Setup
#
# Please run the setup code below

# %%
! wget -q -nc https://raw.githubusercontent.com/taylor-arnold/fds-py/refs/heads/main/funs.py

from funs import *

# %%
import numpy as np
import polars as pl

from plotnine import *
from polars import col as c
theme_set(theme_minimal())

path = "https://raw.githubusercontent.com/ajcollins16/DSST289_Fall2026_AJC/refs/heads/main/"

# %%
dat = pl.read_csv(path + "Data/countries.csv").drop(c.lang)

# %% [markdown]
# ## Grouping and Variable Creation
#
# Today we will continue to work through some data manipulation concepts. The data is now different than what we have seen thus far. Specifically the "countries" dataset is one where we have 135 countries listed by a slew of variables. Specifically information on name of country and region, geographical coordinates (latitude and longitude), life expectancy, happiness rating, population (in millions), the GDP per capita, and others.
#
# Although we will get some more practice with the sorting, selecting, and filtering functions, we will more importantly learn about grouping and variable creating. Specifically:
#
# * Grouping &rarr; used to split the dataset into groups based on the values of one or more columns to better summarize (or analyze) the groups.
# * Variable Creation &rarr; simple practice of adding a new variable to a dataset often through the calculation of already existing columns.

# %% [markdown]
# ### Questions
#
# 1. Start by finding the country with the highest life expectancy (displaying only the one row)

# %% [markdown]
# 1. What country is that?
#
# **Answer (Q1):**

# %% [markdown]
# 2. Now, select all countries that are located in both the northern hemisphere (i.e., latitude greater than 0) and the eastern hemisphere (longitude greater than 0). Display those below

# %% [markdown]
# 3. Next, select all countries that are located in either the northern hemisphere (i.e., latitude greater than 0) or the eastern hemisphere (i.e., longitude greater than 0).

# %% [markdown]
# 3. Does this produce more or less countries than what was found in Q2?
#
# **Answer (Q3):**

# %% [markdown]
# 4. Select only the countries that are in Africa.

# %% [markdown]
# 5. Now, select countries that are in either Africa or Europe without using the `|` (or) operator.

# %% [markdown]
# 6. The population column in our dataset is again given in millions (i.e., 5.265 is 5265000). Create a new column called `raw_pop` that contains the raw population (i.e., the 5265000 as an example should be what you calculate).

# %% [markdown]
# 7. The GDP per capita of the US (according to this dataset) is 78389. Compute the distance (i.e., difference score) of all other countries GDP to the United States, making sure to take the absolute value to not have negatives (`.abs`). This is called the **absolute distance.**

# %% [markdown]
# 8. Find the country **in each region** that has the closest GDP per capita to the United States. Note: You will probably want to first copy your answer above and make changes rather than starting from scratch.

# %% [markdown]
# 9. The United States is, of course, the closest to itself in "Americas". So finally modify the previous code to remove the United States from the data so that we can see what other country it is closest to in its own region. Note: When we say "modify" in these notes, that means to copy and then modify; don't change the original code itself.
