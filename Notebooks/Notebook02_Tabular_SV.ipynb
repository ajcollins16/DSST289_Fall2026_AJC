# %% [markdown]
# <a href="https://colab.research.google.com/github/ajcollins16/DSST289_Fall2026_AJC/blob/main/Notebooks/Notebook02_Tabular_SV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook 02 — Basics of Tabular Data

# %% [markdown]
# **Main Objective**
#
# 1. Explore Tabular Data Structure
# 2. Basic Data Manipulation
#
# ## Setup
#
# Please run the setup code below

# %%
! wget -q -nc https://raw.githubusercontent.com/taylor-arnold/fds-py/refs/heads/main/funs.py

from funs import *

# %%
import numpy as np
import polars as pl

from plotnine import *
from polars import col as c
theme_set(theme_minimal())

path = "https://raw.githubusercontent.com/ajcollins16/DSST289_Fall2026_AJC/refs/heads/main/"

# %%
dat = pl.read_csv(path + "Data/food.csv")

# %% [markdown]
# ## Exploring Tabular Data Structure
#
# Tabular data is data that is organized into rows and columns, where each row usually represents one observation and each column represents a variable or feature of interest. For example, let's look at the food (`dat`) dataset that we loaded above.
#
# Print the contents of the food dataset in the block below (and nothing else).

# %% [markdown]
# 1. When you do this, how many rows are you given and what rows do these come from do you think?
#
# **Answer (Q1):**

# %% [markdown]
# 2. What are the variables that come out as numbers? Then for each what are they "called" (i.e., defined as) by Python?
#
# **Answer (Q2):**

# %% [markdown]
# 3. What are the variables that come out as text and what are they all called?
#
# **Answer (Q3):**

# %% [markdown]
# 4. How many observations are there in the dataset?
#
# **Answer (Q4):**

# %% [markdown]
# 5. How many variables total are there in the dataset?
#
# **Answer (Q5):**

# %% [markdown]
# 6. Can you figure out how the observations are being ordered above?
#
# **Answer (Q6):**

# %% [markdown]
# ## Basic Data Manipulation
#
# Throughout the course, we will need to apply data manipulation tactics to allow us to visualize, analyze, and model the data we have. To best accomplish these data manipulation procedures, we will write these as ***method chains***, which consist of a very specific format. A method chain is like an **assembly line**: you start with a raw dataset at the beginning, and each station performs one step on it before passing the updated version to the next station.
#
# In the code block below we are going to create a method chain that displays the first 10 rows of the food dataset (using `.head(10)`) and then shows the last three rows of those first 10 (using `.tail(3)`).

# %% [markdown]
# 7. What rows, relative to the original dataset, are returned by the sequence of the steps above?
#
# **Answer (Q7):**

# %% [markdown]
# It is important to note that when you run the above code, the `dat` variable remains unchanged. Since we did not define a new variable to become the output of the above code, Python does not force the output to change anything within the variable(s) being called. Therefore, if we print our food `dat` again, it will replicate what we printed at the start of class.

# %% [markdown]
# If we want to save a copy of the output, we need to define the method chain with a new variable name. In the code below, repeat the method chain from above but start it with `dat2 =` to create a new variable `dat2` that is comprised of the last three rows of the first 10 rows.

# %% [markdown]
# Importantly, any time you create a new variable it is important to then place the name of that variable as is at the end so you and we can see what you did. This way you can easily check if you did something wrong.
