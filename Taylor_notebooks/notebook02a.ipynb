# %% [markdown]
# <a href="https://colab.research.google.com/github/ajcollins16/DSST289_Fall2026_AJC/blob/main/Taylor_notebooks/notebook02a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Notebook02a

# %% [markdown]
# ### Setup

# %% [markdown]
# Run all of the following before starting the notebook.

# %%
! wget -q -nc https://raw.githubusercontent.com/taylor-arnold/fds-py/refs/heads/main/funs.py

# %%
import numpy as np
import polars as pl

from funs import *
from plotnine import *
from polars import col as c
theme_set(theme_minimal())

ub = "https://raw.githubusercontent.com/taylor-arnold/fds-py-nb/refs/heads/main/"

# %%
food = pl.read_csv(ub + "data/food.csv").drop(c.description)

# %% [markdown]
# ### Questions

# %% [markdown]
# We are going to do a number of data manipulation exercises here. Apologies that, because we are just getting started, the number of complete analyses and insights we will gain at this point are limited. We will get there soon! We will work with the `food` dataset again. Remember that in all questions you should just print out the results; don't save them unless ask.

# %% [markdown]
# 1. Start by sorting the food data by calories, with the lowest caloric foods at the top.

# %% [markdown]
# 2. Next, sort by calories but with the highest caloric foods at the top.

# %% [markdown]
# 3. And now, sort by the food groups (alphabetical order) and then within each food group by calories. Note: When we say "sort" in general, that means ascending unless otherwise noted.

# %% [markdown]
# 4. Now, take only the columns food group and calories from the dataset. Notice how close your code (should be) to the code in the previous block.

# %% [markdown]
# 5. Let's now chain several methods together. Create a dataset that has the ten items that have the largest amount of calories per serving.

# %% [markdown]
# 6. And now, in the next block of code grab just one row of the data that has the smallest amount of sugar amongst the 10 highest caloric foods.

# %% [markdown]
# 7. Now, select just those rows where the amount of iron is more than 1mg.

# %% [markdown]
# 8. Now, instead, select those rows where the amount of iron is more than *or equal to* 1mg.

# %% [markdown]
# 9. Select those rows where the food group is "fruit" and the iron is greater than 1. Do this with two different calls to `.filter`.

# %% [markdown]
# 10. Repeat the previous question with a single `.filter` by using the `&` symbol.

# %% [markdown]
# 11. Select the rows where the food group is either "fruit" or "vegetable" using the `|` (or) operator.

# %% [markdown]
# 12. What would happen if we replaced the `|` operator with an `&` (and)?

# %% [markdown]
# **Answer**:

# %% [markdown]
# 13. Finally, select the rows that are fruits or vegetables using the `.is_in` method.

# %% [markdown]
# This last one is the preferred way to do this as it generalizes better to more categories and more clearly maps onto the way we commonly thing about being in a set. The `|` operator is very useful for other kinds of selections, such as selecting all of the vegetables OR foods with no saturated fats.
